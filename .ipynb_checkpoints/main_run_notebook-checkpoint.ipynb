# %%
import networkx as nx
from text_filterer import formTokens
from n_gram_graph import gram3Generator
from clustering_coefficient import wordsByClusteringCoefficient
from betweenness_centrality import wordsByBetweennessCentrality
from degree_centrality import wordsByDegreeCentrality
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt

# %%
G=gram3Generator('FilteredTexts/Port.txt')

# %%
wordsByClusteringCoefficient(G)
# Out:
# CLUSTERING COEFFICIENT :
# ------------------------
# Lowest 15 :
# ama  dia  primeiro  escola  mundo
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-5f5a578a09c7> in <module>
# ----> 1 wordsByClusteringCoefficient(G)
#
# ~/Graph_Theoretic_Text_Analysis/clustering_coefficient.py in wordsByClusteringCoefficient(G)
#      22         print("Lowest 15 :")
#      23         for i in range(0,15):
# ---> 24                 print(hola[i][1],end="  ")
#      25
#      26         print("\n\nHighest 15 :")
#
# IndexError: list index out of range

# %%
wordsByBetweennessCentrality(G)
# Out:
# BETWEENNESS CENTRALITY :
# ------------------------
# Lowest 15 :
# certo  escola  okay  todo  mundo  aula  ama  tudo  primeiro  dia
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-f2617146aeca> in <module>
# ----> 1 wordsByBetweennessCentrality(G)
#
# ~/Graph_Theoretic_Text_Analysis/betweenness_centrality.py in wordsByBetweennessCentrality(G)
#      21         print("Lowest 15 :")
#      22         for i in range(0,15):
# ---> 23                 print(hola[i][1],end="  ")
#      24
#      25         print("\n\nHighest 15 :")
#
# IndexError: list index out of range

# %%
wordsByDegreeCentrality(G)
# Out:
# DEGREE CENTRALITY :
# -------------------
# Lowest 15 :
# certo  todo  escola  mundo  ama  dia  primeiro
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-21ca2d994b4a> in <module>
# ----> 1 wordsByDegreeCentrality(G)
#
# ~/Graph_Theoretic_Text_Analysis/degree_centrality.py in wordsByDegreeCentrality(G)
#      21         print("Lowest 15 :")
#      22         for i in range(0,15):
# ---> 23                 print(hola[i][1],end="  ")
#      24
#      25         print("\n\nHighest 15 :")
#
# IndexError: list index out of range

# %%
#################################### Betweenness Centrality ##########################################
BC_dict=dict(nx.betweenness_centrality(G))

nodesizearray=[]
for n in G.nodes:
	nodesizearray.append(1000*BC_dict[n])

figure(num=None, figsize=(50, 50), dpi=80, facecolor='w', edgecolor='k')
plt.subplot(121)
nx.draw(G,node_size=nodesizearray, with_labels=True, font_weight='bold')
######################################################################################################

# %%
###################################   Degree Centrality Plot  ########################################
de_dict=dict(nx.degree_centrality(G))

nodesizearray=[]
for n in G.nodes:
	nodesizearray.append(10000*de_dict[n])

figure(num=None, figsize=(50, 50), dpi=80, facecolor='w', edgecolor='k')
plt.subplot(121)
nx.draw(G,node_size=nodesizearray, with_labels=True, font_weight='bold')
######################################################################################################
